# %% [markdown]
# # **Project Name**    - Hotel Booking Analysis

# %% [markdown]
# ##### **Project Type**    - EDA
# ##### **Contribution**    - Individual

# %% [markdown]
# # **Project Summary -**
# **Have you ever wondered when the best time of year to book a hotel room is? Or the optimal length of stay in order to get the best daily rate? What if you wanted to predict whether or not a hotel was likely to receive a disproportionately high number of special requests? This hotel booking dataset can help you explore those questions**

# %% [markdown]
# **![1407953244000-177513283.webp](data:image/webp;base64,...)This data set contains booking information for a city hotel and a resort hotel, and includes information such as when the booking was made, length of stay, the number of adults, children, and/or babies, and the number of available parking spaces, among other things. All personally identifying information has been removed from the data. Explore and analyze the data to discover important factors that govern the bookings**

# %% [markdown]
# # **GitHub Link -**

# %% [markdown]
# https://github.com/premkrsingh/Capastone-Project-Hotel-Booking-Analysis-Eda/blob/main/Capastone%20Project%20Hotel%20Booking%20Analysis.ipynb

# %% [markdown]
# # **Problem Statement**

# %% [markdown]
# **Write Problem Statement Here.**

# %% [markdown]
# #### **Define Your Business Objective?**

# %% [markdown]
# Answer Here.

# %% [markdown]
# # **General Guidelines** : -

# %% [markdown]
# 1.   Well-structured, formatted, and commented code is required.
# 2.   Exception Handling, Production Grade Code & Deployment Ready Code will be a plus. Those students will be awarded some additional credits.
#
#      The additional credits will have advantages over other students during Star Student selection.
#
#              [ Note: - Deployment Ready Code is defined as, the whole .ipynb notebook should be executable in one go
#                        without a single error logged. ]
#
# 3.   Each and every logic should have proper comments.
# 4. You may add as many number of charts you want. Make Sure for each and every chart the following format should be answered.
#
#
# ```
# # Chart visualization code
# ```
#
#
# *   Why did you pick the specific chart?
# *   What is/are the insight(s) found from the chart?
# * Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.
#
# 5. You have to create at least 20 logical & meaningful charts having important insights.
#
#
# [ Hints : - Do the Vizualization in  a structured way while following "UBM" Rule.
#
# U - Univariate Analysis,
#
# B - Bivariate Analysis (Numerical - Categorical, Numerical - Numerical, Categorical - Categorical)
#
# M - Multivariate Analysis
#  ]

# %% [markdown]
# # ***Let's Begin !***

# %% [markdown]
# ## ***1. Know Your Data***

# %% [markdown]
# ### Import Libraries

# %%
# Import Libraries
import numpy as np
import pandas as pd
from numpy import math
from numpy import loadtxt
import seaborn as sns
import matplotlib.pyplot as plt

# %%
from google.colab import drive
drive.mount('/content/drive')

# %% [markdown]
# ### Dataset Loading

# %%
# Load Dataset
Hotel_booking = pd.read_csv('/content/Hotel_Bookings.csv')

# %% [markdown]
# ### Dataset First View
# **Understand dataset input**
# Find out the total columns and rows of dataset
# Find the data type of each column.
# Find the continuous and categorical data
# Find individual distribution for some of the columns
# Also check the correlation between dependent columns

# %%
# Dataset First Look
Hotel_booking.head()

# %%
Hotel_booking.tail()

# %% [markdown]
# ### Dataset Rows & Columns count

# %%
# Dataset Rows & Columns count
Hotel_booking.shape
print(list(Hotel_booking.columns))

# %% [markdown]
# ### Dataset Information

# %%
# Dataset Info
Hotel_booking.info()

# %% [markdown]
# #### Duplicate Values

# %%
len(Hotel_booking[Hotel_booking.duplicated()])

# %% [markdown]
# # Dataset Duplicate Value Count

# %%
Hotel_booking.duplicated().value_counts()

# %% [markdown]
# #### Missing Values/Null Values

# %%
# Missing Values/Null Values Count
print(Hotel_booking.isnull().count)

# %%
# Visualizing the missing values
plt.figure(figsize =(10,8))
sns.countplot(x=Hotel_booking.duplicated())

# %% [markdown]
# ### What did you know about your dataset?

# %% [markdown]
# In this dataset there are 32 columns and 119390 rows. There is complete analysis of Hotel Booking related query this data set contains booking information for a city hotel and a resort hotel, and includes information such as when the booking was made, length of stay, the number of adults, children, and/or babies, and the number of available parking spaces, among other things. All personally identifying information has been removed from the data.
# Explore and analyze the data to discover important factors that govern the bookings.

# %% [markdown]
# ## ***2. Understanding Your Variables***

# %%
# Dataset Columns
Hotel_booking.columns

# %%
# Dataset Describe
Hotel_booking.describe()

# %% [markdown]
# ### Variables Description

# %% [markdown]
#  0   hotel  : (Resort Hotel or City Hotel)
#  1   is_canceled:Value indicating if the booking was canceled (1) or
#       not (0)
#  2   lead_time  Number of days that elapsed between the entering date
#      of the
#      booking into the PMS and the arrival date
#  3   arrival_date_year :Year of arrival date
#  4   arrival_date_month:Month of arrival date
#  5   arrival_date_week_number :Week number of arrival date
#  6   arrival_date_day_of_month:day of month of arrival date
#  7   stays_in_weekend_nights :Number of weekend nights (Saturday or
#      Sunday) the guest stayed or booked to stay at the hotel
#  8   stays_in_week_nights :Number of week nights (Monday to Friday)
#      the guest stayed or booked to stay at the hotel
#  9   adults:Number of adults
#  10  children:Numbers of children
#  11  babies:number of babies
#  12  meal:Types of meal
#  13  country:origin of country
#  14  market_segment  Market segment designation. In categories, the
#      term “TA” means “Travel Agents” and “TO” means “Tour Operators”
#  15  distribution_channel: Booking distribution channel. The term “TA”
#      means “Travel Agents” and “TO” means “Tour Operators”
#  16  is_repeated_guest Value indicating if the booking name was from a
#      repeated guest (1) or not (0)
#  17  previous_cancellations Number of previous bookings that were
#      cancelled by the customer prior to the current booking
#  18  previous_bookings_not_canceled Number of previous bookings not
#      cancelled by the customer prior to the current booking
#  19  reserved_room_type Code of room type reserved. Code is presented
#      instead of designation for anonymity reasons.
#  20  assigned_room_type Code for the type of room assigned to the
#      booking.
#  21  booking_changes Number of changes/amendments made to the booking
#      from the moment the booking was entered on the PMS until the moment of check-in or cancellation
#  22  deposit_type Indication on if the customer made a deposit to
#      guarantee the booking.
#  23  agent ID of the travel agency that made the booking
#  24  company  ID of the company/entity that made the booking or
#      responsible for paying the booking
#  25  days_in_waiting_list   Number of days the booking was in the
#      waiting list before it was confirmed to the customer
#  26  customer_typeType of booking, assuming one of four
#      categories
#  27  adr Average Daily Rate as defined by dividing the sum of all
#      lodging transactions by the total number of staying nights
#  28  required_car_parking_spaces Number of car parking spaces required by the customer
#  29  total_of_special_requests  Number of special requests made by the
#      customer (e.g. twin bed or high floor)
#  30  reservation_status Reservation last status, assuming one of three
#      categories
#  31  reservation_status_date reservation status by date

# %% [markdown]
# ### Check Unique Values for each variable.

# %%
# Check Unique Values for each variable.
for i in Hotel_booking.columns.tolist():
  print("No of unique values",i,"is",Hotel_booking[i].nunique(),".")

# %% [markdown]
# ## 3. ***Data Wrangling***

# %% [markdown]
# ### Data Wrangling Code

# %%
# Write your code to make your dataset analysis ready.
# here we are copying dataset and named as df
df=Hotel_booking.copy()
# Deleting duplicate values and ready for anlayze data
df=df.drop_duplicates()
df.info()

# %% [markdown]
# ### What all manipulations have you done and insights you found?

# %% [markdown]
# Here we drop duplicated values and clean the data make a chart for show the duplicated value

# %% [markdown]
# ## ***4. Data Vizualization, Storytelling & Experimenting with charts : Understand the relationships between variables***

# %%
# first we deal with null value
df.isna().sum()

# %% [markdown]
# we got null values in children,country, agent and company

# %% [markdown]
# #### Chart - 1

# %%
# Chart - 1 visualization code
plt.figure(figsize=(20,6))
sns.heatmap(df.isnull(),cmap='viridis')

# %%
#here we are delaing with null values with na and 0
children = df['children'].mode()[0]
df['children'].fillna(children,inplace=True)
df['country'].fillna('others',inplace=True)
df['agent'].fillna(0,inplace=True)
df['company'].fillna('unknown',inplace=True)

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# i picked this code and chart to analyze the miss values

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# i got missing values and sort all these

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes it will give good impact with bussiness understanding

# %% [markdown]
# #### Chart - 2

# %%
# Hotel type and preffered hotel type Now just take a look at the unique values of each column in the df_hotel file
df['hotel'].unique()

# %%
# number of bookings
hotelbooking = df['hotel'].value_counts().reset_index()
hotelbooking.columns=['hotel type','number of bookings']
hotelbooking

# %%
#graphical representation
# Chart - 2 visualization code
plt.pie(hotelbooking["number of bookings"],autopct="%1.1f%%",radius=1.5,explode=[0.08]*2)
plt.legend(labels=hotelbooking['hotel type'].value_counts().index.tolist(),loc=(1.1,0.65))
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# i picked this chart because bar graph is more efficient to comparison

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# i got that city hotel is more utilize in compare to resort

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# the positivity is city hotel is more occupied bussiness than resort

# %% [markdown]
# #### Chart - 3

# %%
# Chart - 3 visualization code
# Booking hotels year wise
plt.figure(figsize=(10,6))
sns.countplot(x=df['arrival_date_year'],hue=df['hotel'])
plt.title("Year wise booking")
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# I picked for comparing the value

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# i found that except 2015 year both year have city hotel have more occupied

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# in this chart we can analyze that year wise bussiness and process

# %% [markdown]
# #### Chart - 4

# %%
# Chart - 4 visualization code
# pick business season
data = df["arrival_date_month"].value_counts()
plt.figure(figsize=(10,6))
data.plot(kind='bar',color='r',grid=True)
plt.title("A year data")
plt.xlabel("A year_data")
plt.ylabel("number of guests")
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# It is showing comaprison in good way

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# it is showing august has many guest

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# with this we can find peak time and go for that

# %% [markdown]
# #### Chart - 5

# %%
# Chart - 5 visualization code
# cancellation rate(
cancellationRate=df['is_canceled'].value_counts().reset_index()
cancellationRate
cancellationRate.columns=["cancellation_show","user"]
sns.barplot(x=cancellationRate["cancellation_show"],y=cancellationRate["user"])
plt.title("cancellationRate")
plt.xlabel("booking not cancel guest                      booking cancel guest")
plt.ylabel("number of guest")
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.
# i want to show cancellation of guest with comparison

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here
# it helps to check cancel guest

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here
# it will easily measure cancellation of guest so we can make action

# %% [markdown]
# #### Chart - 6

# %%
# Chart - 6 visualization code
# how many types of rooms are provided through hotels with room preference
room_by_hotel=df["reserved_room_type"].unique()
room_by_hotel
prefer_room_type=df["reserved_room_type"].value_counts().reset_index()
prefer_room_type.columns=["room_type","Number of preference"]
sns.barplot(x=prefer_room_type["room_type"],y=prefer_room_type["Number of preference"])
plt.title("room preference")
plt.ylabel("Number of preference")
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.
# it shows the value easily

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here
# it shows A room type has maximum preference so that it will help to mantaining the same

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here
# it help to business study and maintaining room and facility according their type

# %% [markdown]
# #### Chart - 7
# # **Meal Consumption Analysis**

# %%
# Chart - 7 visualization code
#type of meal offer by hotel and most prefer meal consumption
df["meal"].unique()
meal_df=df["meal"].value_counts().reset_index()
meal_df.columns=["meal_type","number of preference"]
meal_df

# %%
sns.barplot(x=meal_df["meal_type"],y=meal_df["number of preference"])
plt.title("meal graph")
plt.xlabel("meal type")
plt.ylabel("number of preference")
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# In this chart we are analyzing easily

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# BB meal type has more preference

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# it analyze the meal preference for the customer view

# %% [markdown]
# #### Chart - 8
# # **Waiting time Analysis**

# %%
# Chart - 8 visualization code
# Analyse in which type of hotel there is more waiting time and analyse the average of type of hotel there is more waiting time
max_waiting=df.groupby("hotel").max()["days_in_waiting_list"].reset_index()
max_waiting.columns=["hotel","max_waiting_time"]
print(max_waiting)

# %%
plt.figure(figsize=(10,5))
plt.subplot(1,2,2)
sns.barplot(x=max_waiting["hotel"],y=max_waiting["max_waiting_time"])
plt.title("hotel type vs max waiting time")
plt.xlabel("hotel")
plt.ylabel("max_waiting_time")
plt.show()

# %%
avg_waiting=df.groupby("hotel").mean()["days_in_waiting_list"].reset_index()
avg_waiting.columns=["hotel","avg_waiting_time"]
print(avg_waiting)
sns.barplot(x=avg_waiting["hotel"],y=avg_waiting["avg_waiting_time"])
plt.title("hotel vs Avg_waiitng_time")
plt.xlabel("Avg_wating_time")
plt.ylabel("hotel")
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# for the compare hotel and their timing

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# city hotel have max waiting time and avg waiting time

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# we can check hotel and their respective waiting

# %% [markdown]
# #### Chart - 9
# # **Customer wise analysis**

# %%
# Chart - 9 visualization code
# Find out count of customers on basis of customer type
customer_type=df["customer_type"].value_counts().reset_index()
customer_type.columns=["customer_type","Numbers of customer"]
print(customer_type)
plt.figure(figsize=(15,3))
plt.subplot(1,2,1)
sns.barplot(x=customer_type["customer_type"],y=customer_type["Numbers of customer"],palette="magma")
plt.title("Customer_type vs Numbers of customer")
plt.subplot(1,2,2)
plt.pie(df["customer_type"].value_counts(),autopct="%1.1f%%",shadow=True,radius=1.5,explode=[.2]*4)
plt.legend(labels=df["customer_type"].value_counts().index.tolist(),loc=(1.1,.65))
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# both chart shows enough understaing the data

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# the transient has good numner of customers

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# it is good to analyze model of customer view

# %% [markdown]
# #### Chart - 10
# # **country origin customer analysis**

# %%
# Chart - 10 visualization code
# Analyse the data from which country guests are visiting most
country = df["country"].value_counts().reset_index()[:10]
country.columns=["country_name","Number of guests"]
print(country)
plt.pie(country["Number of guests"],autopct="%1.1f%%",shadow=True,explode=[.1]*10,radius=1.3)
plt.legend(labels=country["country_name"].value_counts().index.tolist(),loc=(1.3,.65))
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# for some values pie chart is good to show

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# prt has good number of guest

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# it show the country with number of guest to understand the model

# %% [markdown]
# #### Chart - 11
# # **Distributor channel analysis**

# %%
# Chart - 11 visualization code
# Find out which distribution channel is giving most booking business and Which distribution channel is giving more business to hotels on basis of hotel type
distributor_channel=df["distribution_channel"].value_counts().reset_index()
distributor_channel.columns=("distribution_type","Number of bookings")
print(distributor_channel)
plt.pie(distributor_channel["Number of bookings"],autopct="%1.1f%%",explode=[.1]*5,radius=1,shadow=True)
plt.legend(labels=distributor_channel["distribution_type"].value_counts().index.tolist(),loc=(1,0.65))
plt.show()

# %%
more_business_hotel=df.groupby(["distribution_channel","hotel"])
more_business_hotel_df=pd.DataFrame(round((more_business_hotel["adr"]).agg(np.mean),2)).reset_index().rename(columns={"adr":"average_adr"})
plt.figure(figsize=(7,5))
sns.barplot(x=more_business_hotel_df["distribution_channel"],y=more_business_hotel_df["average_adr"],hue=more_business_hotel_df["hotel"])
plt.ylim(40,100)
plt.xlabel("distribution_channel")
plt.ylabel("avrage-adr")
plt.title("More Business Hotel With Its type")
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# because this chart has good overview of catogrical value

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# ta/to has good consistancy

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# easy to inderstand where is good approach for business

# %% [markdown]
# #### Chart - 12
# # **Agent Wise Booking Analysis**

# %%
# Chart - 12 visualization code
# Remove company data where company is not associated with hotel
df.drop(df[df["agent"]==0].index, inplace=True)
# Find count of each agent to predict which agent has given maximum business which can be considered while providing commission to agent.
df_agent=df["agent"].value_counts().reset_index().rename(columns={'index':'Agent','agent':'Agent_wise_bookings'}).sort_values(by = 'Agent_wise_bookings', ascending = False)
df_agent = df_agent.nlargest(10, ['Agent']) # Find top 5 agents providing maximum business.
plt.figure(figsize = (10,5))
sns.barplot(x = 'Agent', y = 'Agent_wise_bookings', data = df_agent, order = df_agent.sort_values('Agent_wise_bookings', ascending = False).Agent)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# to shows the comparison of agents

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# agent no 531 has good approach

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# it this model easy to understand the best agents

# %% [markdown]
# ## **5. Solution to Business Objective**

# %% [markdown]
# #### What do you suggest the client to achieve Business Objective ?
# Explain Briefly.

# %% [markdown]
# i have tried to make hotel booking concept easy
# the customer can understand the hotel type and the profit compare of peak season, meal consumption,customer analysis,distribution analysis,good agent deals

# %% [markdown]
# # **Conclusion**

# %% [markdown]
# the Hotel booking concept is easy to understand if you know the pros and cons of booking model in this project i have tried to detailed about the pros and cons of hotel booking i have used some chart for understanding the same. I have clean the data delete the duplicated and then approach tries to get unique value after that get prefer season and prefer room type food analysis of comparison agents,waiting time,customer analysis so it can easily analyze the hotel booking model easy understandable.

# %% [markdown]
# ### ***Hurrah! You have successfully completed your EDA Capstone Project !!!***
